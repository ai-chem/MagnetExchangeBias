# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/part_11.csv')

# %%
df
# Out:
#      Unnamed: 0              c1          c2   c3       chemical_formula  \
# 0             0          Zn1 O1  Fe2 Co1 O4  NaN     ['ZnO', 'CoFe2O4']
# 1             1          Co1 O1  Fe2 Co1 O4  NaN     ['CoO', 'CoFe2O4']
# 2             2  Mn1 Zn1 Fe4 O8         NaN  NaN  ['Mn0.50Zn0.50Fe2O4']
# 3             3  Mn1 Zn1 Fe4 O8         NaN  NaN  ['Mn0.50Zn0.50Fe2O4']
# 4             4  Mn1 Zn1 Fe4 O8         NaN  NaN  ['Mn0.50Zn0.50Fe2O4']
# ..          ...             ...         ...  ...                    ...
# 528         528      La1 Fe1 O3      Ni1 O1  NaN      ['LaFeO3', 'NiO']
# 529         529      La1 Fe1 O3      Ni1 O1  NaN      ['LaFeO3', 'NiO']
# 530         530      La1 Fe1 O3      Ni1 O1  NaN      ['LaFeO3', 'NiO']
# 531         531      La1 Fe1 O3      Ni1 O1  NaN      ['LaFeO3', 'NiO']
# 532         532      La1 Fe1 O3      Ni1 O1  NaN      ['LaFeO3', 'NiO']
#
#       coer_oe    crystal_structure  depth_nm  exc_bias_oe  fc_field_t  ...  \
# 0    27800.00    hexagonal, cubic        7.4    -1132.000         5.0  ...
# 1     7800.00         cubcic, cube       7.0     -406.000         5.0  ...
# 2       24.80                cubic      17.0       51.340         0.0  ...
# 3       90.20                cubic      11.0      108.180         0.0  ...
# 4       40.07                cubic      12.0        8.920         0.0  ...
# ..        ...                  ...       ...          ...         ...  ...
# 528   1144.92  orthorhombic, cubic      40.0     -842.644         2.0  ...
# 529   1260.00  orthorhombic, cubic      40.0    -1030.000         3.0  ...
# 530   1322.50  orthorhombic, cubic      35.0    -1144.500         4.0  ...
# 531   1452.60  orthorhombic, cubic      35.0    -1452.600         5.0  ...
# 532   1976.41  orthorhombic, cubic      35.0    -1976.410         6.0  ...
#
#      space_group_core  space_group_shell          structure   structure_  \
# 0               p63mc              fd-3m        ZnO/CoFe2O4  ZnO/CoFe2O4
# 1               fm-3m              fd-3m        CoO/CoFe2O4  CoO/CoFe2O4
# 2               fd-3m                  0  Mn0.50Zn0.50Fe2O4    MnZnFe4O8
# 3               fd-3m                  0    Mn0.5Zn0.5Fe2O4    MnZnFe4O8
# 4               fd-3m                  0    Mn0.5Zn0.5Fe2O4    MnZnFe4O8
# ..                ...                ...                ...          ...
# 528              pnma              fm-3m         LaFeO3-NiO   LaFeO3-NiO
# 529              pnma              fm-3m         LaFeO3-NiO   LaFeO3-NiO
# 530              pnma              fm-3m         LaFeO3-NiO   LaFeO3-NiO
# 531              pnma              fm-3m         LaFeO3-NiO   LaFeO3-NiO
# 532              pnma              fm-3m         LaFeO3-NiO   LaFeO3-NiO
#
#      temperature_k ver_shift_emu_g width_nm            orig_c1  orig_c2  \
# 0              5.0          0.0000      7.4                ZnO  CoFe2O4
# 1              5.0          0.0000      7.0                CoO  CoFe2O4
# 2            300.0          0.0000     17.0  Mn0.50Zn0.50Fe2O4      NaN
# 3            300.0          0.0000     11.0  Mn0.50Zn0.50Fe2O4      NaN
# 4            300.0          0.0000     12.0  Mn0.50Zn0.50Fe2O4      NaN
# ..             ...             ...      ...                ...      ...
# 528            5.0          0.1125     40.0             LaFeO3      NiO
# 529            5.0          0.1240     40.0             LaFeO3      NiO
# 530            5.0          0.1520     35.0             LaFeO3      NiO
# 531            5.0          0.1500     35.0             LaFeO3      NiO
# 532            5.0          0.1700     35.0             LaFeO3      NiO
#
#       formula_combined
# 0    Zn1 O1 Fe2 Co1 O4
# 1    Co1 O1 Fe2 Co1 O4
# 2       Mn1 Zn1 Fe4 O8
# 3       Mn1 Zn1 Fe4 O8
# 4       Mn1 Zn1 Fe4 O8
# ..                 ...
# 528  La1 Fe1 O3 Ni1 O1
# 529  La1 Fe1 O3 Ni1 O1
# 530  La1 Fe1 O3 Ni1 O1
# 531  La1 Fe1 O3 Ni1 O1
# 532  La1 Fe1 O3 Ni1 O1
#
# [533 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 533 entries, 0 to 532
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         533 non-null    int64
#  1   c1                 533 non-null    object
#  2   c2                 322 non-null    object
#  3   c3                 9 non-null      object
#  4   chemical_formula   533 non-null    object
#  5   coer_oe            510 non-null    float64
#  6   crystal_structure  533 non-null    object
#  7   depth_nm           509 non-null    float64
#  8   exc_bias_oe        500 non-null    float64
#  9   fc_field_t         508 non-null    float64
#  10  h_range_max_koe    526 non-null    float64
#  11  id                 533 non-null    int64
#  12  length_d_nm        521 non-null    float64
#  13  mr (emu/g)         430 non-null    float64
#  14  sat_em_g           420 non-null    float64
#  15  shape              493 non-null    object
#  16  space_group_core   532 non-null    object
#  17  space_group_shell  533 non-null    object
#  18  structure          533 non-null    object
#  19  structure_         533 non-null    object
#  20  temperature_k      528 non-null    float64
#  21  ver_shift_emu_g    441 non-null    float64
#  22  width_nm           521 non-null    float64
#  23  orig_c1            533 non-null    object
#  24  orig_c2            322 non-null    object
#  25  formula_combined   533 non-null    object
# dtypes: float64(11), int64(2), object(13)
# memory usage: 108.4+ KB

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
# Данные для круговой диаграммы из колонки df['c1']
orig_c1_counts = df['c1'].value_counts()

# Создание круговой диаграммы для df['c1']
plt.figure(figsize=(8, 8))
plt.pie(orig_c1_counts, labels=orig_c1_counts.index, autopct='%1.1f%%')
plt.title('Pie Chart for formula core')
plt.axis('equal')  # Делает круговую диаграмму круглой
plt.show()

# Данные для круговой диаграммы из колонки df['c2']
orig_c2_counts = df['c2'].value_counts()

# Создание круговой диаграммы для df['c2']
plt.figure(figsize=(8, 8))
plt.pie(orig_c2_counts, labels=orig_c2_counts.index, autopct='%1.1f%%')
plt.title('Pie Chart for formula shell')
plt.axis('equal')  # Делает круговую диаграмму круглой
plt.show()

# %%
orig_c2_counts = df['c1'].value_counts()

# Вычисление общего процента для "Others"
total_count_c2 = sum(orig_c2_counts)
threshold = 0.028
other_count_c2 = orig_c2_counts[orig_c2_counts / total_count_c2 < threshold].sum()

# Фильтрация данных и добавление в "Others"
orig_c2_counts_filtered = orig_c2_counts[orig_c2_counts / total_count_c2 >= threshold]
orig_c2_counts_filtered['Others'] = other_count_c2

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 2)
wedges, texts, autotexts = plt.pie(orig_c2_counts_filtered, labels=orig_c2_counts_filtered.index, autopct='%1.1f%%', textprops=dict(color="black"))
plt.title('Pie Chart for materials of core')
plt.axis('equal')  # Делает круговую диаграмму круглой

# Аннотация для отображения содержимого "Others"
others_content = '\n'.join([f'{label}: {count}' for label, count in orig_c2_counts.items() if label != 'Others' and count < other_count_c2])
plt.text(1.1, 0.5, f'Others:\n{others_content}', verticalalignment='center', horizontalalignment='left', transform=plt.gca().transAxes)

for autotext in autotexts:
    autotext.set_color('black')

plt.show()

# %%
orig_c2_counts = df['c2'].value_counts()

# Вычисление общего процента для "Others"
total_count_c2 = sum(orig_c2_counts)
threshold = 0.028
other_count_c2 = orig_c2_counts[orig_c2_counts / total_count_c2 < threshold].sum()

# Фильтрация данных и добавление в "Others"
orig_c2_counts_filtered = orig_c2_counts[orig_c2_counts / total_count_c2 >= threshold]
orig_c2_counts_filtered['Others'] = other_count_c2

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 2)
wedges, texts, autotexts = plt.pie(orig_c2_counts_filtered, labels=orig_c2_counts_filtered.index, autopct='%1.1f%%', textprops=dict(color="black"))
plt.title('Pie Chart for materials of shell')
plt.axis('equal')  # Делает круговую диаграмму круглой

# Аннотация для отображения содержимого "Others"
others_content = '\n'.join([f'{label}: {count}' for label, count in orig_c2_counts.items() if label != 'Others' and count < other_count_c2])
plt.text(1.1, 0.5, f'Others:\n{others_content}', verticalalignment='center', horizontalalignment='left', transform=plt.gca().transAxes)

# Цвет текста автоподписей должен быть чёрным
for autotext in autotexts:
    autotext.set_color('black')

plt.show()
